# %%
from refine import Refine
import pandas as pd

# %%
df = pd.read_csv('Personal Information.csv')

# %%
df
# Out:
#             id first_name  last_name  Age  Gender         Income State
# 0            1       Jean    Schmidt   19  Female    25000-49999    PA
# 1            2      Larry     Bishop   21    Male    50000-99999    OR
# 2            3     George     Flores   51    Male    50000-99999    NE
# 3            4     George      Lewis   55    Male    50000-99999    MO
# 4            5  Christine      Berry   56  Female    25000-49999    NC
# 5            6      Jesse     Carter   40    Male  100000-249999    TX
# 6            7     Evelyn   Hamilton   43  Female    25000-49999    FL
# 7            8  Christina    Vasquez   29  Female         <24999    AL
# 8            9      Alice      Clark   28  Female    25000-49999    TX
# 9           10    Lillian   Marshall   56  Female         <24999    NJ
# 10          11      Wanda    Bradley   31  Female         <24999    TX
# 11          12   Lawrence    Stanley   57    Male    50000-99999    VA
# ...

# %%
p = Refine(df)

# %%
df = p.export_pandas_frame()

# %%
df
# Out:
#         Column      id     first_name     last_name  Age  Gender  \
# 0            0       1  adfadsgasdgas  fdagthgfdsfd   19  Female
# 1            1       2          Larry        Bishop   21    Male
# 2            2       3         George        Flores   51    Male
# 3            3       4         George         Lewis   55    Male
# 4            4       5      Christine         Berry   56  Female
# 5            5       6          Jesse        Carter   40    Male
# 6            6       7         Evelyn      Hamilton   43  Female
# 7            7       8      Christina       Vasquez   29  Female
# 8            8       9          Alice         Clark   28  Female
# 9            9      10        Lillian      Marshall   56  Female
# 10          10      11          Wanda       Bradley   31  Female
# 11          11      12       Lawrence       Stanley   57    Male
# 12          12      13          Craig         Davis   53    Male
# ...
