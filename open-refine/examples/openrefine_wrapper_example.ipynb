# %%
#Initial import
from open_refine_wrapper import data_explore
import pandas as pd

# %%
#read in pandas dataframe
df = pd.read_csv('example_input_table.csv')

# %%
#Overlook of the original dataframe
df.head()
# Out:
#        b      a      c      d      e   label                 date
# 0  2.395  3.447  4.587  3.895  1.793  orange  2014-01-02 07:00:00
# 1  2.734  3.431  8.798  5.074  2.091  yellow  2014-01-01 08:00:00
# 2  2.424  3.365  5.941  5.268  2.241  yellow  2014-01-17 14:00:00
# 3  2.696  3.265  3.562  6.330  1.775    blue  2014-01-15 17:00:00
# 4  2.719  3.257  7.079  5.686  2.509   green  2014-01-08 19:00:00

# %%
#Invoke the open refine gui for data exploration
p = data_explore(df,"http://127.0.0.1:3333/")

# %%
#Save the project back to our dataframe
# after calling export_pandas_frame, the openRefine project will be deleted automatically
df = p.export_pandas_frame()

# %% [markdown]
# After executing the above command you will see a screen like this:

# %%
#screenshot of the open refine GUI
from IPython.display import Image
Image(filename='../figures/Screenshot_OpenRefine.png')

# %%
#The dataframe after my exploration
df.head()
# Out:
#    Column      b      a      c      d      e   label                 date
# 0       0  2.395  3.447  4.587  3.895  1.793  orange  2014-01-02 07:00:00
# 1       1  2.734  3.431  8.798  5.074  2.091  yellow  2014-01-01 08:00:00
# 2       2  2.424  3.365  5.941  5.268  2.241  yellow  2014-01-17 14:00:00
# 3       3  2.696  3.265  3.562  6.330  1.775    blue  2014-01-15 17:00:00
# 4       4  2.719  3.257  7.079  5.686  2.509   green  2014-01-08 19:00:00
